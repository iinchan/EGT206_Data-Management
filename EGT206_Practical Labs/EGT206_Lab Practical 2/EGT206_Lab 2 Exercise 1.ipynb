# %% [markdown]
# # Ex1 - Getting and Knowing your Data

# %%
# upload local data (xx.csv) to google colab
from google.colab import files # files (class) [choose files to import]
upload = files.upload() #"." - intelligent input
# Out:
#      <input type="file" id="files-4f5eb79b-7c69-42d5-b49c-fec3528d5f51" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f5eb79b-7c69-42d5-b49c-fec3528d5f51">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# mount with Google Drive
from google.colab import drive
drive.mount("/content/drive") # mount google drive
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Read from data.csv and assign it to a variable called users and use the 'user_id' as index

# %%
users = pd.read_csv("data1.csv", index_col = "user_id")

# %% [markdown]
# ### Step 3. See the first 25 entries

# %%
users.head(25)
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# 6         42      M      executive    98101
# 7         57      M  administrator    91344
# 8         36      M  administrator     5201
# 9         29      M        student     1002
# 10        53      M         lawyer    90703
# 11        39      F          other    30329
# 12        28      F          other     6405
# 13        47      M       educator    29206
# 14        45      M      scientist    55106
# 15        49      F       educator    97301
# 16        21      M  entertainment    10309
# 17        30      M     programmer     6355
# 18        35      F          other    37212
# 19        40      M      librarian     2138
# 20        42      F      homemaker    95660
# ...

# %% [markdown]
# ### Step 4. See the last 10 entries

# %%
users.tail(10)
# Out:
#          age gender     occupation zip_code
# user_id
# 934       61      M       engineer    22902
# 935       42      M         doctor    66221
# 936       24      M          other    32789
# 937       48      M       educator    98072
# 938       38      F     technician    55038
# 939       26      F        student    33319
# 940       32      M  administrator     2215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841

# %% [markdown]
# ### Step 5. What is the number of rows in the dataset?

# %%
users.shape[0]
# Out:
# 943

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
users.shape[1]
# Out:
# 4

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
users.columns
# Out:
# Index(['age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %% [markdown]
# ### Step 8. Print only the occupation column

# %%
occupation = users["occupation"]
print(occupation)
# Out:
# user_id
# 1         technician
# 2              other
# 3             writer
# 4         technician
# 5              other
#            ...
# 939          student
# 940    administrator
# 941          student
# 942        librarian
# 943          student
# Name: occupation, Length: 943, dtype: object

# %% [markdown]
# ### Step 9. How many different occupations are in this dataset?

# %%
occup_list = occupation.value_counts() # to count how many people are there in each occupation
print(occup_list)
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: occupation, dtype: int64

# %%
occup_sum = occup_list.value_counts().sum() # to count how many occupation are there in the list and sum it up
print(occup_sum)
# Out:
# 21

# %% [markdown]
# ### Step 10. What is the most frequent occupation?

# %%
most_occur = occup_list.head(1) # Because "most" is asked
print(most_occur)
# Out:
# student    196
# Name: occupation, dtype: int64

# %% [markdown]
# ### Step 11. Summarize the DataFrame.

# %%
users.describe()
# Out:
#               age
# count  943.000000
# mean    34.051962
# std     12.192740
# min      7.000000
# 25%     25.000000
# 50%     31.000000
# 75%     43.000000
# max     73.000000

# %% [markdown]
# ### Step 12. Summarize only the occupation column

# %%
occupation.describe()
# Out:
# count         943
# unique         21
# top       student
# freq          196
# Name: occupation, dtype: object

# %% [markdown]
# ### Step 13. What is the mean age of users?

# %%
age = users["age"] # declare a variable name to store the user's age
# print(age)

age_mean = age.mean()
print(age_mean)
# Out:
# 34.05196182396607

# %% [markdown]
# ### Step 14. What is the age with least occurrence?

# %%
age_list = age.value_counts() # to count the age of the users
print(age_list)
# Out:
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
#       ..
# 7      1
# 66     1
# 11     1
# 10     1
# 73     1
# Name: age, Length: 61, dtype: int64

# %%
age_list.tail() # to find out the age with least occurence
# Out:
# 7     1
# 66    1
# 11    1
# 10    1
# 73    1
# Name: age, dtype: int64
